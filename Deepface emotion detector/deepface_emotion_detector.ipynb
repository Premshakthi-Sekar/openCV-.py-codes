# %%
import cv2

# %%
from deepface import DeepFace

# %%
img= cv2.imread('happy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB ))

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:17<00:00,  4.37s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 2.5502612288619275e-05,
#   'disgust': 1.472014454773074e-08,
#   'fear': 0.003006000042660162,
#   'happy': 99.97674822807312,
#   'sad': 0.005287389649311081,
#   'surprise': 0.004803954288945533,
#   'neutral': 0.010130863665835932},
#  'dominant_emotion': 'happy',
#  'region': {'x': 217, 'y': 65, 'w': 120, 'h': 120},
#  'age': 28,
#  'gender': 'Woman',
#  'race': {'asian': 53.39159965515137,
#   'indian': 9.186331182718277,
#   'black': 12.196611613035202,
#   'white': 2.3233069106936455,
#   'middle eastern': 1.092610228806734,
#   'latino hispanic': 21.809542179107666},
#  'dominant_race': 'asian'}

# %%
facecascade= cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGBA2GRAY)

#detect faces
faces= facecascade.detectMultiScale(gray)

#draw rectangles around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 255), 2)

# %%
font= cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font,3,
           (0,255,0),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB ))
